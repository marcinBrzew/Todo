# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinBrzew/Todo/blob/master/GetOnlineStockData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#if you get error reading dataframe - update Pandas
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader
import pandas_datareader.data as reader
import datetime as dt
import matplotlib.pyplot as plt

# %%
end= dt.datetime.now()
start = dt.date(2022,1,1)
stocks=['AAPL','MSFT','TSLA']

# %%
df=reader.get_data_yahoo(stocks,start,end)['Close']

# %%
df

# %%
#Visulalization
#df.plot()
#plt.show()
daily_returns=df.pct_change()
daily_returns.plot()
plt.show()

# %%
daily_cum_returns=(daily_returns+1).cumprod()
daily_cum_returns

# %%
daily_cum_returns.plot()
plt.show()
